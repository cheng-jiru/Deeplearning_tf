# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# 2.12.0
# sys.version_info(major=3, minor=8, micro=1, releaselevel='final', serial=0)
# matplotlib 3.7.1
# numpy 1.23.5
# pandas 2.0.3
# sklearn 1.2.2
# tensorflow 2.12.0
# keras.api._v2.keras 2.12.0

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

print(x_valid.shape, y_valid.shape)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
print(np.max(x_train), np.min(x_train))
# Out:
# 255 0

# %%
55000*28*28
# Out:
# 43120000

# %%
x_train.reshape(-1, 1).shape
# Out:
# (43120000, 1)

# %%
#通过原有sk的标准化进行处理
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# x_train: [None, 28, 28] -> [None, 784]
#先reshape变为二维（相当于1列）的目的是对每一个像素点进行标准化（让其等价）
x_train_scaled = scaler.fit_transform(
    x_train.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)
#这个是验证集，验证集用的也是训练集的均值和方差
x_valid_scaled = scaler.transform(
    x_valid.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)
#这个是测试集
x_test_scaled = scaler.transform(
    x_test.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)

# %%
print(np.max(x_train_scaled), np.min(x_train_scaled))
# Out:
# 2.0231433 -0.8105136

# %%
"""
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))
"""

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])


model.compile(loss="sparse_categorical_crossentropy",
              optimizer = keras.optimizers.SGD(0.001),
              metrics = ["accuracy"])

# %%
#如果再次直接fit是接着之前的进行训练的，如果要从头训练，要重新执行上面代码
history = model.fit(x_train_scaled, y_train, epochs=20,
                    validation_data=(x_valid_scaled, y_valid))
# Out:
# Epoch 1/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.9221 - accuracy: 0.7041 - val_loss: 0.6222 - val_accuracy: 0.7912
# Epoch 2/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5818 - accuracy: 0.7995 - val_loss: 0.5209 - val_accuracy: 0.8212
# Epoch 3/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.5135 - accuracy: 0.8206 - val_loss: 0.4771 - val_accuracy: 0.8356
# Epoch 4/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4770 - accuracy: 0.8328 - val_loss: 0.4530 - val_accuracy: 0.8446
# Epoch 5/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4524 - accuracy: 0.8410 - val_loss: 0.4347 - val_accuracy: 0.8480
# Epoch 6/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4346 - accuracy: 0.8474 - val_loss: 0.4203 - val_accuracy: 0.8532
# Epoch 7/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4203 - accuracy: 0.8515 - val_loss: 0.4098 - val_accuracy: 0.8570
# Epoch 8/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.4082 - accuracy: 0.8559 - val_loss: 0.4006 - val_accuracy: 0.8600
# Epoch 9/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3990 - accuracy: 0.8589 - val_loss: 0.3940 - val_accuracy: 0.8620
# Epoch 10/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3904 - accuracy: 0.8618 - val_loss: 0.3889 - val_accuracy: 0.8652
# Epoch 11/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3829 - accuracy: 0.8648 - val_loss: 0.3831 - val_accuracy: 0.8660
# Epoch 12/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3763 - accuracy: 0.8662 - val_loss: 0.3776 - val_accuracy: 0.8644
# Epoch 13/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3701 - accuracy: 0.8685 - val_loss: 0.3739 - val_accuracy: 0.8668
# Epoch 14/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3644 - accuracy: 0.8707 - val_loss: 0.3712 - val_accuracy: 0.8692
# Epoch 15/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3595 - accuracy: 0.8720 - val_loss: 0.3668 - val_accuracy: 0.8704
# Epoch 16/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3546 - accuracy: 0.8741 - val_loss: 0.3634 - val_accuracy: 0.8728
# Epoch 17/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3503 - accuracy: 0.8760 - val_loss: 0.3597 - val_accuracy: 0.8706
# Epoch 18/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3459 - accuracy: 0.8771 - val_loss: 0.3558 - val_accuracy: 0.8712
# Epoch 19/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3421 - accuracy: 0.8785 - val_loss: 0.3542 - val_accuracy: 0.8758
# Epoch 20/20
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.3382 - accuracy: 0.8801 - val_loss: 0.3545 - val_accuracy: 0.8720

# %%
print(type(history.history))
# Out:
# <class 'dict'>

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test, verbose=0)
# Out:
# [0.39086541533470154, 0.8586000204086304]
