# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.10.1
# sys.version_info(major=3, minor=8, micro=17, releaselevel='final', serial=0)
# matplotlib 3.7.2
# numpy 1.24.4
# pandas 2.0.3
# sklearn 1.3.0
# tensorflow 2.10.1
# keras.api._v2.keras 2.10.0

# %%
# !ls
# Out:
# ceshi.ipynb
# day1

# %%
fashion_mnist = keras.datasets.fashion_mnist
(x_train_all, y_train_all), (x_test, y_test) = fashion_mnist.load_data()
x_valid, x_train = x_train_all[:5000], x_train_all[5000:]
y_valid, y_train = y_train_all[:5000], y_train_all[5000:]

print(x_valid.shape, y_valid.shape)
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
# x = (x - u) / std

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# x_train: [None, 28, 28] -> [None, 784]
x_train_scaled = scaler.fit_transform(
    x_train.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)
x_valid_scaled = scaler.transform(
    x_valid.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)
x_test_scaled = scaler.transform(
    x_test.astype(np.float32).reshape(-1, 1)).reshape(-1, 28, 28)

# %%
# tf.keras.models.Sequential()

"""
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))
"""

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(300, activation='relu'),
    keras.layers.Dense(100, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])

# relu: y = max(0, x)
# softmax: 将向量变成概率分布. x = [x1, x2, x3],
#          y = [e^x1/sum, e^x2/sum, e^x3/sum], sum = e^x1 + e^x2 + e^x3

# reason for sparse: y->index. y->one_hot->[]
model.compile(loss="sparse_categorical_crossentropy",
              optimizer = keras.optimizers.SGD(0.001),
              metrics = ["accuracy"])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 300)               235500
#
#  dense_1 (Dense)             (None, 100)               30100
#
#  dense_2 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Tensorboard, earlystopping, ModelCheckpoint
logdir = './callbacks'
if not os.path.exists(logdir): #如果不存在callbacks文件夹，就创建
    os.mkdir(logdir)

#模型保存路径
output_model_file = os.path.join(logdir,
                                 "fashion_mnist_model.h5")

callbacks = [
    keras.callbacks.TensorBoard(logdir),#tensorflow提供画图使用
    keras.callbacks.ModelCheckpoint(output_model_file,#保存模型的最佳参数
                                    save_best_only = True),
    #大家可以继续调小min_delta，默认监控的指标是验证集的monitor='val_loss'
    keras.callbacks.EarlyStopping(patience=5, min_delta=1e-3),
]
#没有触发EarlyStopping的话，把epochs改大一些
history = model.fit(x_train_scaled, y_train, epochs=100,
                    validation_data=(x_valid_scaled, y_valid),
                    callbacks = callbacks)
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3055 - accuracy: 0.8903 - val_loss: 0.3344 - val_accuracy: 0.8804
# Epoch 2/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3027 - accuracy: 0.8918 - val_loss: 0.3353 - val_accuracy: 0.8798
# Epoch 3/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.3004 - accuracy: 0.8933 - val_loss: 0.3335 - val_accuracy: 0.8828
# Epoch 4/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2982 - accuracy: 0.8945 - val_loss: 0.3300 - val_accuracy: 0.8840
# Epoch 5/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2960 - accuracy: 0.8944 - val_loss: 0.3294 - val_accuracy: 0.8822
# Epoch 6/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2935 - accuracy: 0.8955 - val_loss: 0.3289 - val_accuracy: 0.8840
# Epoch 7/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2916 - accuracy: 0.8964 - val_loss: 0.3301 - val_accuracy: 0.8812
# Epoch 8/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2893 - accuracy: 0.8978 - val_loss: 0.3273 - val_accuracy: 0.8828
# Epoch 9/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2871 - accuracy: 0.8986 - val_loss: 0.3287 - val_accuracy: 0.8810
# Epoch 10/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2850 - accuracy: 0.8995 - val_loss: 0.3260 - val_accuracy: 0.8830
# Epoch 11/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2830 - accuracy: 0.9004 - val_loss: 0.3218 - val_accuracy: 0.8840
# Epoch 12/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2811 - accuracy: 0.9007 - val_loss: 0.3251 - val_accuracy: 0.8878
# Epoch 13/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2791 - accuracy: 0.9014 - val_loss: 0.3222 - val_accuracy: 0.8844
# Epoch 14/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2770 - accuracy: 0.9024 - val_loss: 0.3229 - val_accuracy: 0.8844
# Epoch 15/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2751 - accuracy: 0.9025 - val_loss: 0.3192 - val_accuracy: 0.8850
# Epoch 16/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2735 - accuracy: 0.9038 - val_loss: 0.3196 - val_accuracy: 0.8858
# Epoch 17/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2713 - accuracy: 0.9040 - val_loss: 0.3188 - val_accuracy: 0.8872
# Epoch 18/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2696 - accuracy: 0.9045 - val_loss: 0.3168 - val_accuracy: 0.8874
# Epoch 19/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2679 - accuracy: 0.9054 - val_loss: 0.3170 - val_accuracy: 0.8862
# Epoch 20/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2661 - accuracy: 0.9059 - val_loss: 0.3162 - val_accuracy: 0.8868
# Epoch 21/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2641 - accuracy: 0.9068 - val_loss: 0.3173 - val_accuracy: 0.8876
# Epoch 22/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2628 - accuracy: 0.9063 - val_loss: 0.3147 - val_accuracy: 0.8864
# Epoch 23/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2609 - accuracy: 0.9077 - val_loss: 0.3150 - val_accuracy: 0.8862
# Epoch 24/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2589 - accuracy: 0.9088 - val_loss: 0.3129 - val_accuracy: 0.8846
# Epoch 25/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2575 - accuracy: 0.9091 - val_loss: 0.3145 - val_accuracy: 0.8904
# Epoch 26/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2555 - accuracy: 0.9100 - val_loss: 0.3128 - val_accuracy: 0.8878
# Epoch 27/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2541 - accuracy: 0.9109 - val_loss: 0.3117 - val_accuracy: 0.8892
# Epoch 28/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2525 - accuracy: 0.9104 - val_loss: 0.3103 - val_accuracy: 0.8880
# Epoch 29/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2510 - accuracy: 0.9115 - val_loss: 0.3112 - val_accuracy: 0.8890
# Epoch 30/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2492 - accuracy: 0.9120 - val_loss: 0.3130 - val_accuracy: 0.8866
# Epoch 31/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2475 - accuracy: 0.9127 - val_loss: 0.3131 - val_accuracy: 0.8872
# Epoch 32/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2460 - accuracy: 0.9128 - val_loss: 0.3098 - val_accuracy: 0.8878
# Epoch 33/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2446 - accuracy: 0.9135 - val_loss: 0.3081 - val_accuracy: 0.8864
# Epoch 34/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2431 - accuracy: 0.9149 - val_loss: 0.3082 - val_accuracy: 0.8894
# Epoch 35/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2414 - accuracy: 0.9146 - val_loss: 0.3074 - val_accuracy: 0.8894
# Epoch 36/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2400 - accuracy: 0.9155 - val_loss: 0.3088 - val_accuracy: 0.8894
# Epoch 37/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2388 - accuracy: 0.9164 - val_loss: 0.3077 - val_accuracy: 0.8920
# Epoch 38/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2370 - accuracy: 0.9172 - val_loss: 0.3069 - val_accuracy: 0.8934
# Epoch 39/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2352 - accuracy: 0.9172 - val_loss: 0.3093 - val_accuracy: 0.8896
# Epoch 40/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2338 - accuracy: 0.9173 - val_loss: 0.3082 - val_accuracy: 0.8902
# Epoch 41/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2326 - accuracy: 0.9182 - val_loss: 0.3075 - val_accuracy: 0.8922
# Epoch 42/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2312 - accuracy: 0.9196 - val_loss: 0.3116 - val_accuracy: 0.8852
# Epoch 43/100
# 1719/1719 [==============================] - 5s 3ms/step - loss: 0.2299 - accuracy: 0.9194 - val_loss: 0.3075 - val_accuracy: 0.8896

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test, verbose=0)
# Out:
# [0.34555116295814514, 0.8780999779701233]
