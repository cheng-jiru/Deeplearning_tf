# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import sklearn
import pandas as pd
import os
import sys
import time
import tensorflow as tf

from tensorflow import keras

print(tf.__version__)
print(sys.version_info)
for module in mpl, np, pd, sklearn, tf, keras:
    print(module.__name__, module.__version__)
# Out:
# 2.10.1
# sys.version_info(major=3, minor=8, micro=17, releaselevel='final', serial=0)
# matplotlib 3.7.2
# numpy 1.24.4
# pandas 2.0.3
# sklearn 1.3.0
# tensorflow 2.10.1
# keras.api._v2.keras 2.10.0

# %%
fashion_mnist=keras.datasets.fashion_mnist
(x_train_all,y_train_all),(x_test,y_test)=fashion_mnist.load_data()
x_valid,x_train=x_train_all[:5000],x_train_all[5000:]
y_valid,y_train=y_train_all[:5000],y_train_all[5000:]
print(x_valid.shape,y_valid.shape)
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (5000, 28, 28) (5000,)
# (55000, 28, 28) (55000,)
# (10000, 28, 28) (10000,)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train.astype(np.float32).reshape(-1,1)).reshape(-1,28,28)
x_valid_scaled=scaler.transform(x_valid.astype(np.float32).reshape(-1,1)).reshape(-1,28,28)
x_test_scaled=scaler.transform(x_test.astype(np.float32).reshape(-1,1)).reshape(-1,28,28)

# %%
model=keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28,28]))
for i in range(10):
    model.add(keras.layers.Dense(50,activation='selu'))
model.add(keras.layers.Dense(10,activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy',optimizer=keras.optimizers.SGD(0.001),metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 50)                39250
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 50)                2550
#
#  dense_3 (Dense)             (None, 50)                2550
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 50)                2550
#
#  dense_6 (Dense)             (None, 50)                2550
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 50)                2550
#
#  dense_9 (Dense)             (None, 50)                2550
#
#  dense_10 (Dense)            (None, 10)                510
#
# =================================================================
# Total params: 62,710
# Trainable params: 62,710
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(model.layers)
# Out:
# 12

# %%
logdir='./dnn-callbacks'
if not os.path.exists(logdir):
    os.mkdir(logdir)

output_model_file=os.path.join(logdir,'fashion_mnist_model.h5')
callbacks=[
    keras.callbacks.TensorBoard(logdir),
    keras.callbacks.ModelCheckpoint(output_model_file,save_best_only=True),
    keras.callbacks.EarlyStopping(patience=5,min_delta=1e-3),

]

history=model.fit(x_train_scaled,y_train,epochs=100,validation_data=(x_valid_scaled,y_valid),callbacks=callbacks)
# Out:
# Epoch 1/100
# 1719/1719 [==============================] - 13s 6ms/step - loss: 0.8591 - accuracy: 0.6930 - val_loss: 0.6129 - val_accuracy: 0.7858
# Epoch 2/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5772 - accuracy: 0.7909 - val_loss: 0.5229 - val_accuracy: 0.8210
# Epoch 3/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.5086 - accuracy: 0.8141 - val_loss: 0.4819 - val_accuracy: 0.8358
# Epoch 4/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4691 - accuracy: 0.8306 - val_loss: 0.4599 - val_accuracy: 0.8438
# Epoch 5/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4423 - accuracy: 0.8393 - val_loss: 0.4361 - val_accuracy: 0.8494
# Epoch 6/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.4226 - accuracy: 0.8478 - val_loss: 0.4182 - val_accuracy: 0.8578
# Epoch 7/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.4062 - accuracy: 0.8537 - val_loss: 0.4089 - val_accuracy: 0.8602
# Epoch 8/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3933 - accuracy: 0.8584 - val_loss: 0.3995 - val_accuracy: 0.8612
# Epoch 9/100
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3821 - accuracy: 0.8624 - val_loss: 0.3919 - val_accuracy: 0.8674
# Epoch 10/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3720 - accuracy: 0.8656 - val_loss: 0.3939 - val_accuracy: 0.8630
# Epoch 11/100
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.3633 - accuracy: 0.8688 - val_loss: 0.3837 - val_accuracy: 0.8680
# Epoch 12/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3556 - accuracy: 0.8712 - val_loss: 0.3770 - val_accuracy: 0.8718
# Epoch 13/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3493 - accuracy: 0.8736 - val_loss: 0.3778 - val_accuracy: 0.8700
# Epoch 14/100
# 1719/1719 [==============================] - 11s 6ms/step - loss: 0.3429 - accuracy: 0.8765 - val_loss: 0.3681 - val_accuracy: 0.8722
# Epoch 15/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3367 - accuracy: 0.8783 - val_loss: 0.3617 - val_accuracy: 0.8756
# Epoch 16/100
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.3316 - accuracy: 0.8802 - val_loss: 0.3685 - val_accuracy: 0.8726
# Epoch 17/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3270 - accuracy: 0.8819 - val_loss: 0.3660 - val_accuracy: 0.8724
# Epoch 18/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3217 - accuracy: 0.8831 - val_loss: 0.3600 - val_accuracy: 0.8770
# Epoch 19/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3177 - accuracy: 0.8848 - val_loss: 0.3547 - val_accuracy: 0.8782
# Epoch 20/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3131 - accuracy: 0.8866 - val_loss: 0.3633 - val_accuracy: 0.8750
# Epoch 21/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3099 - accuracy: 0.8879 - val_loss: 0.3516 - val_accuracy: 0.8770
# Epoch 22/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.3054 - accuracy: 0.8889 - val_loss: 0.3591 - val_accuracy: 0.8754
# Epoch 23/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.3019 - accuracy: 0.8905 - val_loss: 0.3503 - val_accuracy: 0.8788
# Epoch 24/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2980 - accuracy: 0.8922 - val_loss: 0.3468 - val_accuracy: 0.8786
# Epoch 25/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2951 - accuracy: 0.8930 - val_loss: 0.3614 - val_accuracy: 0.8754
# Epoch 26/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2920 - accuracy: 0.8937 - val_loss: 0.3496 - val_accuracy: 0.8762
# Epoch 27/100
# 1719/1719 [==============================] - 9s 6ms/step - loss: 0.2887 - accuracy: 0.8950 - val_loss: 0.3452 - val_accuracy: 0.8788
# Epoch 28/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2851 - accuracy: 0.8966 - val_loss: 0.3442 - val_accuracy: 0.8788
# Epoch 29/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2824 - accuracy: 0.8973 - val_loss: 0.3473 - val_accuracy: 0.8786
# Epoch 30/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2800 - accuracy: 0.8984 - val_loss: 0.3431 - val_accuracy: 0.8808
# Epoch 31/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2767 - accuracy: 0.9002 - val_loss: 0.3408 - val_accuracy: 0.8804
# Epoch 32/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2741 - accuracy: 0.9012 - val_loss: 0.3384 - val_accuracy: 0.8824
# Epoch 33/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2716 - accuracy: 0.9021 - val_loss: 0.3460 - val_accuracy: 0.8774
# Epoch 34/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2692 - accuracy: 0.9028 - val_loss: 0.3424 - val_accuracy: 0.8790
# Epoch 35/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2666 - accuracy: 0.9044 - val_loss: 0.3377 - val_accuracy: 0.8832
# Epoch 36/100
# 1719/1719 [==============================] - 9s 5ms/step - loss: 0.2640 - accuracy: 0.9047 - val_loss: 0.3399 - val_accuracy: 0.8816
# Epoch 37/100
# 1719/1719 [==============================] - 10s 6ms/step - loss: 0.2620 - accuracy: 0.9060 - val_loss: 0.3477 - val_accuracy: 0.8776

# %%
def plot_learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(8, 5))
    plt.grid(True)
    plt.gca().set_ylim(0, 1)
    plt.show()

plot_learning_curves(history)

# %%
model.evaluate(x_test_scaled, y_test, verbose=0)
# Out:
# [0.3744908571243286, 0.8690000176429749]
